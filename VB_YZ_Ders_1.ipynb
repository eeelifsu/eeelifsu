# %% [markdown]
# <a href="https://colab.research.google.com/github/eeelifsu/eeelifsu/blob/main/VB_YZ_Ders_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRO BAŞLANGIÇ**

# %%
2
# Out:
# 2

# %%
2+5
# Out:
# 7

# %%
3*9
# Out:
# 27

# %% [markdown]
# **variables-değişkenler**

# %%
800/6
# Out:
# 133.33333333333334

# %%
10-80
# Out:
# -70

# %%
age = 100

# %%
age
# Out:
# 100

# %%
age + 5
# Out:
# 105

# %%
age/5
# Out:
# 20.0

# %%
x = 13
y=12

# %%
x
# Out:
# 13

# %%
x+y
# Out:
# 25
