# %% [markdown]
# <a href="https://colab.research.google.com/github/eeelifsu/eeelifsu/blob/main/VB_YZ_ders2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3 + 5
# Out:
# 8

# %%
887/7
# Out:
# 126.71428571428571

# %%
44-49
# Out:
# -5

# %% [markdown]
# # **Değişken**

# %%
age = 29

# %%
age
# Out:
# 29

# %%
age + 4
# Out:
# 33

# %%
age * 12 + 4
# Out:
# 352

# %%
age + age
# Out:
# 58

# %%
age = 30

# %%
age
# Out:
# 30

# %%
age + 23
# Out:
# 53

# %%
yas = 20

# %%
abi = 30

# %%
kardes=2

# %%
age + yas + abi + kardes
# Out:
# 82

# %%
50/5
# Out:
# 10.0

# %%
40*3
# Out:
# 120

# %%
900/7
# Out:
# 128.57142857142858

# %%
type(10)
# Out:
# int

# %%
type(12.4)
# Out:
# float

# %%
type(11/6)
# Out:
# float

# %%
type(age)
# Out:
# int

# %%
x= -100

# %%
type(x)
# Out:
# int

# %%
y = 900/7

# %%
y
# Out:
# 128.57142857142858

# %%
type(128.57142857142858)
# Out:
# float

# %%
type(y+x)
# Out:
# float

# %%
myFloat = 3.1456

# %%
type(myFloat)
# Out:
# float

# %%
#camelCase
#snake_case

# %%
5**3 # ** üslü ifadeler
# Out:
# 125

# %%
10/4
# Out:
# 2.5

# %%
10%4 # mod alma
# Out:
# 2

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
print("Merhaba Dünya")
# Out:
# Merhaba Dünya

# %%
name = "Gürhan"

# %%
type(name) # string
# Out:
# str

# %%
'Gürhan'
# Out:
# 'Gürhan'

# %%
"Türkiyenin başkenti Ankara'dır"
# Out:
# "Türkiyenin başkenti Ankara'dır"

# %%
name.capitalize()
# Out:
# 'Gürhan'

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
isim = "Elifsu Dallı"

# %%
isim.capitalize()
# Out:
# 'Elifsu dallı'

# %%
x = "10"

# %%
x
# Out:
# '10'

# %%
x + 10 # hata sebebi,farklı değişkenler toplamamız
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_509/3365201894.py in <cell line: 0>()
# ----> 1 x + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
isim
# Out:
# 'Elifsu Dallı'

# %%
isim.upper()
# Out:
# 'ELIFSU DALLI'

# %%
buyuk_isim = print(isim.upper())
# Out:
# ELIFSU DALLI

# %%
len(isim)
# Out:
# 12

# %% [markdown]
# # **INDEX**

# %%
myString = "Hello World"

# %%
len(myString)
# Out:
# 11

# %%
myString[0]
# Out:
# 'H'

# %%
myString[5]
# Out:
# ' '

# %%
ad = "Hüseyin Gürhan Temiz"

# %%
ad
# Out:
# 'Hüseyin Gürhan Temiz'

# %%
len(ad)
# Out:
# 20

# %%
ad[12]
# Out:
# 'a'

# %%
len(ad) - 1 # son indenks
# Out:
# 19

# %%
ad[len(ad)-1] # son karakteri alma
# Out:
# 'z'

# %%
ad[-1] # son karakteri alma kısa yöntem
# Out:
# 'z'

# %%
barcode = "ABC123456789"

# %%
barcode[0]
# Out:
# 'A'

# %%
barcode[3]
# Out:
# '1'

# %%
barcode[0] + barcode[1] + barcode[2]
# Out:
# 'ABC'

# %%
barcode[::]
# Out:
# 'ABC123456789'

# %%
barcode[3::]
# Out:
# '123456789'

# %%
barcode[5:8:] # 3 dahil 8 dahil değil!
# Out:
# '345'

# %%
barcode[1:5:]
# Out:
# 'BC12'

# %%
barcode[0:7:2] # sıfırdan yediye kadar 2 atlayarak ilerle, 7 dahil değil
# Out:
# 'AC24'

# %%
barcode[0:9:2]
# Out:
# 'AC246'

# %%
barcode = "ABCDE123123982" # tek satırda DE al

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode.split()
# Out:
# ['ABCDE123123982']

# %%
name = "Gürhan Temiz"

# %%
name.split()
# Out:
# ['Gürhan', 'Temiz']

# %%
type(name.split())
# Out:
# list

# %% [markdown]
# # **List**

# %%
myList = [10, 20, 30]

# %%
type(myList)
# Out:
# list

# %%
x=15
y=25
z=35

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [15, 25, 35]

# %%
myList[0]
# Out:
# 15

# %%
len(myList)
# Out:
# 3

# %%
myList.append(11)

# %%
myList
# Out:
# [15, 25, 35, 50, 30, 11]

# %%
len(myList)
# Out:
# 6

# %%
yas = input("yasınızı giriniz:")
# Out:
# yasınızı giriniz:25

# %%
yas
# Out:
# '25'

# %%
myList = ["Gürhan", 15, 25]

# %%
myList
# Out:
# ['Gürhan', 15, 25]

# %%
myList[0]
# Out:
# 'Gürhan'

# %%
mylist[1]
# Out:
# 20

# %%
myList.append("Elifsu")

# %%
len(myList)
# Out:
# 4

# %%
myList
# Out:
# ['Gürhan', 15, 25, 'Elifsu']

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
type(myList[0])
# Out:
# str

# %%
type(myList[1])
# Out:
# int

# %%
myBestList = [10, 20, 3.15,"furkan", [1,2,3]]

# %%
myBestList
# Out:
# [10, 20, 3.15, 'furkan', [1, 2, 3]]

# %%
len(myBestList)
# Out:
# 5

# %%
myBestList[3]
# Out:
# 'furkan'

# %%
myBestList[4]
# Out:
# [1, 2, 3]

# %%
myBestList
# Out:
# [10, 20, 3.15, 'furkan', [1, 2, 3]]

# %%
myBestList[4][2]
# Out:
# 3

# %%
myBestList[-1][-1]
# Out:
# 3

# %%
fruit_list = ["banana", "apple"]

# %%
calorie_list = [200, 100]

# %%
fruit_list[1]
# Out:
# 'apple'

# %%
calorie_list[1]
# Out:
# 100

# %%
fitness_dic =  {"banana":200, "apple":100}

# %%
type(fitness_dic)
# Out:
# dict

# %%
fitness_dic["apple"] #anahtar değer uyumu
# Out:
# 100
